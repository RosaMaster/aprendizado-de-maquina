# %% [markdown]
# ## Exercício de Apoio Semana 02
#
# Crie a KB utilizando o SINTA:
#
# - KB (Knowledge Base) na área de crédito:
#
#
# R1) Se Renda = Alta e Despesa = Alta
#
#        Então Cadastro = Regular
#
#
#
# R9)   Se valRenda >= 10.00
#
#          Então Renda = Alta
#
#          Senão Renda = Baixa
#
# R2) Se Renda = Alta e Despesa = Baixa
#
#        Então Cadastro = Bom
#
#
#
# R10) Se valRenda >= 6.000
#
#          Então Despesa = Alta
#
#          Senão Despesa = Baixa
#
# R3) Se Renda = Baixa e Despesa = Alta
#
#        Então Cadastro = Ruim
#
#
#
# R11) Se Qtde_Prest >= 12
#
#          Então nPrest = Alto
#
#          Senão nPrest = Baixo
#
# R4) Se Renda = Baixa e Despesa = Baixa
#
#           Então Cadastro = Regular
#
#
#
# R12) Se Prestação >= 1000
#
#          Então valPrest = Alto
#
#          Senão valPrest = Baixo
#
# R5) Se nPrest = Baixo e valPrest = Baixo
#
#        Então Operação = Boa
#
#
#
#
#
# R13) Se Cadastro = Ruim
#
#          Então Crédito = Não
#
# R6) Se nPrest = Alto e valPrest = Baixo
#         Então Operação = Boa
#
#
#
#
#
# R14) Se Operação = Ruim
#
#             Então Crédito = Não
#
# R7) Se nPrest = Baixo e valPrest = Alto
#
#        Então Operação = Boa
#
#
#
#
#
# R15) Se Cadastro = Bom e Operação = Boa
#
#          Então Crédito = Sim
#
# R8) Se nPrest = Alto e valPrest = Alto
#
#        Então Operação = Ruim
#
#
#
# R16) Se Cadastro = Regular e Operação = Boa
#
#          Então Crédito = Analista
#
#
#
#
#
# OBS. Implemente as regras com “SENÃO” como duas regras disjuntas.
#
# Exemplo:
#
# Se A então B senão C ficaria:
#
# Se A então B
#
# Se not A então C
#
# Monte a interface para suportar as seguintes situações:
#
# valRenda = 3000; valDespesa = 6000; Qtde_Prest = 6 e Prestacao = 500 Objetivo: Crédito
# valRenda = 11000; valDespesa = 4000; Qtde_Prest = 6 e Prestacao = 800 Objetivo: Crédito
#
#
# Execute cada uma das situações e indique o resultado retornado.
#
#
#
# Observações:
